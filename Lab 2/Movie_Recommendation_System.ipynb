# %% [markdown]
# ## Ομάδα 193
#
# Στοιχεία Μέλους 1: Λουκία Παυλανά ΑΜ:03118711
#
# Στοιχεία Μέλους 2: Ηλίας Αντωνίου ΑΜ:03119705

# %% [markdown]
# # Τεχνητή Νοημοσύνη: Εργαστηριακή Άσκηση 2
# ---
#
# Ο στόχος της εργασίας είναι η κατασκευή ενός συστήματος προτάσεων (Recommendation System) για ταινίες. Οι προτάσεις αυτές θα πηγάζουν τόσο από τα χαρακτηριστικά της ταινίας όσο και από ορισμένες αξιολογήσεις του κάθε χρήστη.
#
# Στα δεδομένα της άσκησης περιλαμβάνονται ένα αρχείο με το όνομα movies_metadata.csv το όποιο περιέχει τα χαρακτηριστικά κάθε ταινίας όπως θέμα, σκηνοθέτης ηθοποιοί, λέξεις κλειδιά κ.α. από το imdb καθώς και τα αρχεία ratings.csv τα όποια περιέχουν πραγματικές αξιολογήσεις χρηστών, χωρισμένες σε train και σε test.

# %% [markdown]
# # Εκφώνηση
# Στην παρούσα εργασία σας ζητείται να μελετήσετε και να υλοποιήσετε τα παρακάτω:<br>
#
# ### Μέρος 1
# Στο μέρος 1 και 2 θα εργαστείτε μόνο με το αρχείο movies_metadata.csv, ενώ στο μέρος τρία θα δουλέψετε και με τα αρχεία των αξιολογήσεων.
# #### Ερώτημα 1α
#
# Αρχικά θα πρέπει, αφού μελετήσετε τη δομή και τα χαρακτηριστικά του movies_metadata.csv, να κατασκευάσετε μια βάση γνώσης για την Prolog η όποια ουσιαστικά θα αποτελεί τον κόσμο με τον όποιο θα εργαστείτε στην συνέχεια. Τα κατηγορήματα που θα δημιουργηθούν θα σας βοηθήσουν και στην κατασκευή του recommender και θα είναι της μορφής:
#
# ```
# director(Movie, Director).
# genre(Movie, Genre).
# ```
# #### Ερώτημα 1β
#
# Αφού δημιουργήσετε τον κόσμο του προβλήματος, στη συνέχεια καλείστε να δημιουργήσετε, σε Prolog, απλούς κανόνες οι οποίοι θα βρίσκουν όλες τις ταινίες με:
# 1.	Κοινό θέμα (κάποιες λέξεις σχετικά με το genre κοινές)
# 2.	Αρκετά κοινό θέμα (κάποιες λιγότερες λέξεις σχετικά με το genre κοινές π.χ. 3)
# 3.	Σχετικά κοινό θέμα (λίγες λέξεις σχετικές με το genre κοινές π.χ. 1)
# 4.	Κοινός σκηνοθέτης
# 5.	Ακριβώς ίδια πλοκή (κάποιες λέξεις κλειδιά της πλοκής κοινές)
# 6.	Σχετικά ίδια πλοκή (κάποιες λιγότερες λέξεις κλειδιά κοινές)
# 7.	Ίδιους τους βασικούς ηθοποιούς (και τους 3)
# 8.	Αρκετά ίδιους βασικούς ηθοποιούς (ορισμένους βασικούς ηθοποιούς κοινούς π.χ. 2)
# 9.	Σχετικά ίδιους ηθοποιούς (π.χ. 1 από τους 3)
# 10.	Ίδια γλώσσα
# 11.	Είναι έγχρωμες ή ασπρόμαυρες
# 12. Κοινό studio παραγωγής
# 13. Κοινή χώρα παραγωγής
# 14. Ίδια δεκαετία
#
# Αξίζει να σημειωθεί ότι στα παραπάνω μπορείτε να προσθέσετε περισσότερα ερωτήματα ή να αλλάξετε την κλιμακωσιμότητα των queries (πέρα από το ίδιο, αρκετά ίδιο, σχετικά ίδιο) που θα κατασκευάσετε(π.χ. μια κλίμακα από 1 στα 5 όπου αυτό είναι δυνατόν), μιας και αυτά στην συνέχεια θα χρησιμοποιηθούν για την λειτουργία του recommender. Έτσι μπορείτε να προσθέσετε queries με τα όποια μπορεί να παράγονται καλύτερες συστάσεις  (το αρχείο movie_metadata.csv περιέχει πολλές πληροφορίες ακόμα για κάθε ταινία όπως έτος κυκλοφορίας, βαθμολογία στο imdb, facebοok_likes κ.α.). Το συγκεκριμένο μέρος εργασίας είναι προπαρασκευαστικό οπότε όσο καλύτερα και πλουσιότερα τα ερωτήματα που θα φτιάξετε σε αυτό το μέρος τόσο καλύτερη θα είναι η απόδοσή των συστημάτων συστάσεων των επόμενων ερωτημάτων.
#
# Περισσότερες πληροφορίες για το dataset μπορείτε να διαβάσετε σε αυτό το [Link](https://www.kaggle.com/georgefila/movies-metadata).
# ### Μέρος 2: Recommendation System
# Στο σημείο αυτό καλείστε με βάση αυτά που κάνατε στο μέρος 1 να κατασκευάσετε queries τα όποια θα σας επιστρέφουν παρόμοιες (σε χαρακτηριστικά) ταινίες. Τα ερωτήματα αυτά θα είναι κλιμακούμενα, δηλαδή θα υπάρχουν ερωτήματα που επιστρέφουν αρκετά κοινές ταινίες αλλά και που επιστρέφουν λιγότερο και λιγότερο κοινές (σε μια κλίμακα π.χ. από 1 σε 5). Για παράδειγμα:
#
# ```
# find_simmilar_movies_5("Pirates Of The Caribbean", M).
# M = "Pirates Of The Caribbean: On Stranger Tides"
# M = "The Chronicles Of Narnia"
# M = "Prince Of Persia: The Sands Of Time"
# ...
# ```
# Για παράδειγμα, το παραπάνω ερώτημα θα επιστρέφει αρκετά κοινές σε περιεχόμενο ταινίες με την ταινια "Pirates Of The Caribbean". Θα υπάρχουν και αντίστοιχα ερωτήματα που θα βρίσκουν λιγότερο όμοιες ταινίες. Ο δείκτης ομοιότητας των ταινιών είναι αυθαίρετος και μπορείτε να τον ορίσετε εσείς όπως θέλετε, αρκεί να υπάρχει κάποια λογική σύνδεση με τα δεδομένα που περιέχονται στο αρχείο movies_metadata.csv.
#
# Συνεπώς η συνάρτηση που θα κάνει τις προτάσεις (recommendation) με είσοδο μια ταινία πρέπει να επιστρέφει-εκτυπώνει μια λίστα με τις προτεινόμενες ταινίες κατά φθίνουσα σειρά ομοιότητας.
#
#
# ###3ο Μέρος: Recommendation System Με βάση τις προτιμήσεις - Αξιολογήσεις του χρήστη
#
#
# Σε αυτό το σημείο θα εργαστείτε με τα αρχεία ratings τα όποια περιέχουν αξιολογήσεις (από 1 μέχρι 5) για τις παραπάνω ταινίες. Το προηγούμενο σύστημα συστάσεων προτείνει στον χρήστη ταινίες αποκλειστικά με βάση την ομοιότητά τους. Σε αυτό το σημείο θα γίνει μια αναβάθμιση του συστήματος έτσι ώστε να παράγονται καλύτερες  συστάσεις οι όποιες θα λαμβάνουν υπόψιν και τις προτιμήσεις του χρήστη, οι όποιες θα εξάγονται από τις αξιολογήσεις που έχει κάνει μέχρι στιγμής.
#
# Η εκπαίδευση του recommender θα γίνεται ως εξής:
#
# Για κάθε ταινία θα υπάρχει ένα score το όποιο αρχικά θε είναι ίσο με 0 και θα διαμορφώνεται από τις αξιολογήσεις κάθε user. Έτσι για έναν χρήστη με βάση τις αξιολογήσεις που υπάρχουν στο αρχείο train_ratings θα πρέπει:
#
# 1.	Για κάθε ταινία που έχει βαθμολογήσει να βρίσκονται οι κοινές ταινίες ανά κλίμακα και στο μέχρι τώρα σκορ κάθε παρόμοιας ταινίας θα προστίθεται ένα βάρος το όποιο θα μπορούσε να είναι το ποσοστό ομοιότητας της ταινίας (δηλαδή ένα βάρος για κάθε κλίμακα, αν δύο ταινίες μοιάζουν ενισχύουμε το βάρος που προσθέτουμε από το να μοιάζουν λιγότερο) επί τον βαθμό που έχει βάλει ο χρήστης για την αρχική ταινία (διαφορετικό είναι ο χρήστης να έχει βάλει 5/5 ή 1/5 σε μια ταινία από 3/5).
#
# 2. Στη συνέχεια, ανάλογα με το σκορ που έχει σχηματιστεί για κάθε ταινία, θα επιλέγεται αν αυτή θα μπορούσε να είναι προτεινόμενη για τον χρήστη ή όχι και θα μετράμε το πόσο καλά τα πήγε το σύστήμά μας με βάση ορισμένες μετρικές.
#
# Η λογική πίσω από την παραπάνω διαδικασία είναι ότι παρόμοιες ταινίες θα έχουν ανάλογο βαθμό. Για παράδειγμα αν ένας χρήστης έχει αξιολογήσει αρκετές  ταινίες οι όποιες είναι sci-fiction με 5/5 τότε μια ταίνια sci-fiction την όποια δεν έχει δεί λογικά θα του αρέσει και θα έπρεπε να την προτείνουμε.
#
# Μετά την εκπαίδευση του συστήματος σας καλείστε να δοκιμάσετε τον recommender που κατασκευάσατε στην πράξη. Για τον σκοπό αυτό θα φορτώσετε το αρχείο test_ratings.csv όπου περιέχονται οι αξιολογήσεις του ίδιου χρήστη για άλλες ταινίες. Το σύστημά σας πρέπει να προβλέπει αν μια ταινία θα πρέπει να προταθεί στον χρήστη. Μια ταίνια θεωρούμε οτι προτείνεται στον  χρήστη, αν έχει βαθμό μεγαλύτερο του 3 στο test_ratings. Συνεπώς για την επίβλεψη του συστήματός σας θα πρέπει για κάθε μια από τις ταινίες του αρχείου test_ratings.csv να προβλέψετε εάν θα αρέσει στο χρήστη ή όχι ώστε να την προτείνετε.
#
# ΠΡΟΣΟΧΗ! Η "βαθμολογία" που θα υπολογίσετε για κάθε ταινία κατά το training δεν είναι απαραίτητα πρόβλεψη της βαθμολογίας που θα έβαζε ο χρήστης.
#
# Στην συνέχεια, σε συνδιασμό με τις πραγματικές απαντήσεις του χρήστη θα αξιολογήσετε το σύστημά σας χρησιμοποιόντας τις μετρικές: precision, recall, f1 οι οποίες είναι οι πλέον γνωστές μετρικές και ευρέως χρησιμοποιούμενες τεχνικές για την επίβλεψη-μέτρηση απόδοσης ανάλογων συστημάτων.
#
# 1. Precision: Δείχνει πόσο ακριβές είναι το σύστημα. Υπολογίζει πόσα από τα στιγμιότυπα τα όποια προβλέψαμε ότι ανήκουν σε μια κλάση όντως ανήκουν σε αυτή. Η μετρική αυτή μας δίνει μια εικόνα σχετικά με τον αριθμό των ταινίων που προβλέψαμε ως προτεινόμενες ενώ δεν θα έπρεπε.
#
# 2. Recall: Υπολογίζει πόσα από τα στιγμιότυπα που ανήκουν σε μια κλάση (π.χ. προτεινόμενες ταινίες) προβλέφθηκαν σωστά.
#
# 3. F1: Είναι ένας μέσος μεταξύ των παραπάνω δυο μετρικών, έτσι ώστε να διατηρείται μια ισορροπία μεταξύ τους. Υπολογίζεται από την παρακάτω σχέση:
#
# $$F_1=2\frac{Precision\times{Recall}}{Precision+Recall}$$
#
# Οι παραπάνω συναρτήσεις παρέχονται από την βιβλιοθήκη scikit-learn.
#
# Τέλος για την καλύτερη επίβλεψη του συστήματος σας μπορείτε να εκπαιδεύσετε  τον recommender σας με ένα υποσύνολο ταινίων από ελάχιστες, λίγες μέχρι και πολλές (π.χ. 3, 5, 10, 50, ...) για να μελετήσετε κατά πόσο σας βοηθούν οι επιπλέον αξιολογήσεις κάθε φορά (δηλαδή κατά πόσο βελτιώνονται οι παραπάνω μετρικές στο test set).
#
# Έτσι π.χ. μπορείτε να εντοπίσετε περιπτώσεις όπως για παράδειγμα ότι με έναν recommender μπορεί να μην επιτυγχάνετε πολύ υψηλό σκορ όσο με άλλους, αλλά το βέλτιστο σκόρ σας επιτυγχάνεται πολύ γρηγόρα π.χ. με μόνο 10 ταινίες αντί 100. Έτσι για παράδειγμα αν ο αλγόριθμος τα πηγαίνει πολύ καλά για τρεις ταινίες και στη συνέχεια το σκορ βελτιώνεται ελάχιστα τότε αυτός ενδείκνυται για ένα σύστημα συστάσεων για νέους χρήστες όπου δεδομένου λίγων ταινιών ο αλγόριθμος είναι σε θέση να το να προτείνει καλές συστάσεις. Ενώ αν η καλύτερη απόδοση του αλγορίθμου σας είναι βέλτιστη με περισσότερες ταινίες π.χ. 50 τότε αυτός ο αλγόριθμος συστάσεων ενδείκνυται για παλιούς χρήστες με πολλές αξιολόγησεις.

# %% [markdown]
# ---
# ## Κατασκευή Περιβάλλοντος Εργασίας
# ---
# ### Διάβασμα Αρχείων στο Colab (Μόνο για το Colab)
# Αν η υλοποίηση γίνει στο google colab τότε μπορεί να χρησιμοποιηθεί το google drive ως file system. Για να γίνει Mount το google drive τρέχουμε τον παρακάτω κώδικα και κλικάρουμε στο link που θα μας εμφανιστεί.
#
# ```
# from google.colab import drive
# drive.mount('/content/drive')
# import os
# os.listdir('/gdrive/My Drive')
# ```
# Έπειτα στην σελίδα που άνοιξε επιλέγουμε το mail μας και στο επόμενο παράθυρο που θα μας ανοίξει πατάμε Να επιτρέπεται. Στην συνέχεια αντιγράφουμε τον κωδικό που θα μας βγάλει και τον κάνουμε paste στο Input που έχει ανοίξει στο colab. Έτσι πλέον αν έχουμε ανεβάσει ένα αρχείο στο google drive μπορούμε να το βρούμε στην θέση:
#
# ```
# movies_filename = '/gdrive/My Drive/' + movies_metadata.csv
# ```
# Μπορούμε πλέον κανονικά να δουλέψουμε φτιάχνοντας φακέλους ή αρχεία και γενικότερα κάνοντας οτιδήποτε θα κάναμε αν ήμασταν τοπικά.
#
# ### Prolog μέσω Python
#
# Το πακέτο που θα χρησιμοποιηθεί για την επικοινωνία Python και Prolog είναι το pyswip (https://pypi.org/project/pyswip/). Για να δουλέψει το Pyswip  χρειάζεται να υπάρχει το Swi-Prolog το όποιο αν δουλεύουμε τοπικά πρέπει να το εγκαταστήσουμε, ακολουθώντας αντίστοιχες οδηγίες στην σελίδα του εργαλείου. Για να γίνει του Swi-Prolog η εγκατάσταση στο Google Colab πρέπει να τρέξουμε τον παρακάτω κώδικα:
#
# ```
# !sudo apt-get install software-properties-common
# !sudo apt-add-repository ppa:swi-prolog/stable
# !sudo apt-get update
# !sudo apt-get install swi-prolog
# ```
# Σε κάποιο σημείο της εκτέλεσης εμφανίζεται ένα μήνυμα ότι πρέπει να πατήσουμε enter σε ένα input για να συνεχίσει η διαδικασία. Έπειτα από αυτό η εκτέλεση θα συνεχίσει χωρίς κάποιο πρόβλημα.
#
# Τέλος πρέπει να εγκαταστήσουμε το pyswip (**όπου και να δουλεύουμε**) όπως παρακάτω:
#
# ```
# !pip isntall pyswip
# ```

# %% [markdown]
# ---
# #Κώδικας για κατασκευή περιβάλλοντος εργασίας
#
# ##Μόνο για Google Colab
#
# Κώδικας για να γίνει Mount to Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive',force_remount=False)

import os
path="Colab_Noteboks/AI_2023/LAB_2" # με ευκόλο τρόπο μπορείτε να αλλάξετε το path που είναι αποθηκευμένα τα αρχεία σας
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %%capture
#install swi-prolog
# !sudo apt-get install software-properties-common
# !sudo apt-add-repository ppa:swi-prolog
# !sudo apt-get update
# !sudo apt-get install swi-prolog
#install pyswip
# !pip install pyswip

# %% [markdown]
# # **Μέρος 1: Μελέτη των Metadata, Δημιουργία κόσμου και των βασικών queries.**

# %%
import pandas as pd
from pyswip import Prolog

# %%
# Η βιβλιοθήκη pandas είναι χρήσιμη για την εργασία με τέτοια δεδομένα
import pandas as pd
path = '/content/drive/MyDrive/Colab_Notebooks/AI_2023/LAB_2/'
# Διάβασμα του αρχείου 'movie_metadata.csv'
data = pd.read_csv(path + "movies_metadata.csv")
#Στο csv υπαρχούν κελία με nan τιμές
#Στις θέσεις αυτές βάζουμε 'UNK' πράγμα που  κάνουμε με την παρακάτω συνάρτηση
data.fillna("UNK", inplace=True)
# Preview the first 5 lines of the loaded data
data.head()
# Out:
#    Unnamed: 0     budget                                    genres  \
# 0           0  237000000  Action|Adventure|Fantasy|Science Fiction
# 1           1  300000000                  Adventure|Fantasy|Action
# 2           2  245000000                    Action|Adventure|Crime
# 3           3  250000000               Action|Crime|Drama|Thriller
# 4           4  260000000          Action|Adventure|Science Fiction
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                        plot_keywords  language  \
# 0  culture clash|future|space war|space colony|so...   English
# 1  ocean|drug abuse|exotic island|east india trad...   English
# 2  spy|based on novel|secret agent|sequel|mi6|bri...  Français
# 3  dc comics|crime fighter|terrorist|secret ident...   English
# 4  based on novel|mars|medallion|space travel|pri...   English
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                             overview  popularity  ...  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577  ...
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615  ...
# 2  A cryptic message from Bond’s past sends him o...  107.376788  ...
# 3  Following the death of District Attorney Harve...  112.312950  ...
# 4  John Carter is a war-weary, former military ca...   43.926995  ...
#
#                                           tagline  \
# 0                     Enter the World of Pandora.
# 1  At the end of the world, the adventure begins.
# 2                           A Plan No One Escapes
# 3                                 The Legend Ends
# 4            Lost in our world, found in another.
#
#                                 movie_title vote_average  num_voted_users  \
# 0                                    Avatar          7.2            11800
# 1  Pirates of the Caribbean: At World's End          6.9             4500
# 2                                   Spectre          6.3             4466
# 3                     The Dark Knight Rises          7.6             9106
# 4                               John Carter          6.1             2124
#
#   title_year                   country      director_name     actor_1_name  \
# 0     2009.0  United States of America      James Cameron      Zoe Saldana
# 1     2007.0  United States of America     Gore Verbinski    Orlando Bloom
# 2     2015.0            United Kingdom         Sam Mendes  Christoph Waltz
# 3     2012.0  United States of America  Christopher Nolan    Michael Caine
# 4     2012.0  United States of America     Andrew Stanton     Lynn Collins
#
#        actor_2_name       actor_3_name
# 0  Sigourney Weaver       Stephen Lang
# 1   Keira Knightley  Stellan Skarsgård
# 2       Léa Seydoux      Ralph Fiennes
# 3       Gary Oldman      Anne Hathaway
# 4   Samantha Morton       Willem Dafoe
#
# [5 rows x 27 columns]

# %%
# prolog.assertz('(directed_by(X,Y) :- findall(M,director(M,X),Y))')

# %%
def clean_text(text):
    text = text.replace(u'\xa0', u'')
    text = text.replace(u"'", u'')
    return text

def remove_brackets(text):
    text = text.replace(u'{', u'')
    text = text.replace(u"[", u'')
    text = text.replace(u'}', u'')
    text = text.replace(u"]", u'')
    text = text.replace(u", ", u',')
    return text

def remove_quotes(text):
    text = text.replace(u"'", u'')
    text = text.replace(u'"', u'')
    return text

# %%
#create World
#Ορίζουμε τον κόσμο μας
prolog = Prolog()

#Για κάθε row του πίνακα φτιάχνουμε τα κατηγορήματα που θέλουμε να αποθηκέυσουμε
#αρχικά σε μια λίστα με το όνομα literals
literals = []
movie_score = {}
gen = {}

for row in data.itertuples(index = True, name = 'Pandas'):
    movie_title = clean_text(getattr(row, 'movie_title'))

    for budget in str(getattr(row, 'budget')).split(" "):
        if(budget != "0"):
            literals.append("budget('" + movie_title + "','" + budget + "')")

    genres = getattr(row, 'genres').split("|")
    if(genres[0] != "UNK"):
        literals.append("genre_no('" + movie_title +"','" + str(len(genres)) + "')")
        combi = []
        for genre in genres:
            literals.append("genre('" + movie_title + "','" + genre + "')")
            if genre not in gen:
              gen[genre] = 1
            else:
              gen[genre] += 1

    plot_keywords = getattr(row, 'plot_keywords').split("|")
    if(plot_keywords[0] != "UNK"):
        literals.append("plot_keywords_no('" + movie_title + "','" + str(len(plot_keywords)) + "')")
        for plot_keyword in plot_keywords:
            literals.append("plot_keyword('" + movie_title + "','" + clean_text(plot_keyword) + "')")
    else:
        literals.append("plot_keywords_no('" + movie_title + "','0')")

    for popularity in str(getattr(row, 'popularity')).split(" "):
        if(popularity != "0.0"):
            literals.append("popularity('" + movie_title + "','" + popularity + "')")

    for prod_company in remove_brackets(getattr(row, 'production_companies')).split(","):
        if(prod_company[0:7] == "'name':"):
            literals.append("prod_company('" + movie_title + "','" + remove_quotes(prod_company[8:]) + "')")

    for release_date in getattr(row, 'release_date').split(" "):
        if(release_date != "UNK"):
            literals.append("release_date('" + movie_title + "','" + release_date + "')")

    for gross in str(getattr(row, 'gross')).split(" "):
        if(gross != "0"):
            literals.append("gross('" + movie_title + "','" + gross + "')")

    for duration in str(getattr(row, 'duration')).split(" "):
        if(duration!="0.0"):
            literals.append("duration('" + movie_title + "','" + duration + "')")

    for spoken_language in remove_brackets(getattr(row, 'spoken_languages')).split(","):
        if(spoken_language[0:12] == "'iso_639_1':"):
            literals.append("spoken_language('" + movie_title + "','" + remove_quotes(spoken_language[13:]) + "')")

    for vote_avg in str(getattr(row, 'vote_average')).split(" "):
        if(vote_avg != "0.0"):
            literals.append("vote_avg('" + movie_title + "','" + vote_avg + "')")

    for num_voted_users in str(getattr(row, 'num_voted_users')).split(" "):
        if(num_voted_users != "0"):
            literals.append("num_voted_users('" + movie_title + "','" + num_voted_users + "')")

    for title_year in str(getattr(row, 'title_year')).split(" "):
        if(title_year != "UNK"):
            literals.append("title_year('" + movie_title + "','" + title_year[0:4] + "')")

    for country in getattr(row, 'country').split("\n"):
        if(country != "UNK"):
            literals.append("country('" + movie_title + "','" + clean_text(country) + "')")

    for director in getattr(row, 'director_name').split("\n"):
        if(director != "UNK"):
            literals.append("director('" + movie_title + "','" + clean_text(director) + "')")

    for actor in getattr(row, 'actor_1_name').split("\n"):
        if(actor != "UNK"):
            literals.append("actor('" + movie_title + "','" + clean_text(actor) + "')")

    for actor in getattr(row, 'actor_2_name').split("\n"):
        if(actor != "UNK"):
            literals.append("actor('" + movie_title + "','" + clean_text(actor) + "')")

    for actor in getattr(row, 'actor_3_name').split("\n"):
        if(actor != "UNK"):
            literals.append("actor('" + movie_title + "','" + clean_text(actor) + "')")

    for title_year in str(getattr(row, 'title_year')).split(" "):
        if(title_year != "UNK"):
          #dec=  int(float(title_year)) % 100.0
          decade= title_year[2]
          literals.append("decade('" + movie_title + "','" + str(decade) + "')")


for genre in gen:
  if gen[genre] < 300 and gen[genre] > 100:
    literals.append("rare_genre('" + genre + "').")

#Η Prolog θέλει τα κατηγορήματά της με την σειρά

literals.sort()

f = open("world.pl", "w")
for literal in literals:
    f.write(literal + "." + "\n")
f.close()

# %%
predicates = []

predicates.append("genre1_aux(X,G1) :- genre(X,G1).")
predicates.append("genre1(X,Y) :- genre1_aux(X,G1),genre1_aux(Y,G1),X\=Y.")
predicates.append("genre2_aux(X,G1,G2) :- genre(X,G1),genre(X,G2),G1@<G2.")
predicates.append("genre2(X,Y) :- genre2_aux(X,G1,G2),genre2_aux(Y,G1,G2),X\=Y.")
predicates.append("genre3_aux(X,G1,G2,G3) :- genre(X,G1),genre(X,G2),genre(X,G3),G1@<G2,G2@<G3.")
predicates.append("genre3(X,Y) :- genre3_aux(X,G1,G2,G3),genre3_aux(Y,G1,G2,G3),X\=Y.")
predicates.append("genre4_aux(X,G1,G2,G3,G4) :- genre(X,G1),genre(X,G2),genre(X,G3),genre(X,G4),G1@<G2,G2@<G3,G3@<G4.")
predicates.append("genre4(X,Y) :- genre4_aux(X,G1,G2,G3,G4),genre4_aux(Y,G1,G2,G3,G4),X\=Y.")
predicates.append("genre5_aux(X,G1,G2,G3,G4,G5) :- genre(X,G1),genre(X,G2),genre(X,G3),genre(X,G4),genre(X,G5),G1@<G2,G2@<G3,G3@<G4,G4@<G5.")
predicates.append("genre5(X,Y) :- genre5_aux(X,G1,G2,G3,G4,G5),genre5_aux(Y,G1,G2,G3,G4,G5),X\=Y.")
predicates.append("genre6_aux(X,G1,G2,G3,G4,G5,G6) :- genre(X,G1),genre(X,G2),genre(X,G3),genre(X,G4),genre(X,G5),genre(X,G6),G1@<G2,G2@<G3,G3@<G4,G4@<G5,G5@<G6.")
predicates.append("genre6(X,Y) :- genre6_aux(X,G1,G2,G3,G4,G5,G6),genre6_aux(Y,G1,G2,G3,G4,G5,G6),X\=Y.")

predicates.append("common_director(X,Y) :- director(X,Z),director(Y,Z),X\=Y.")

predicates.append("plot1(X,Y) :- plot1_aux(X,P1),plot1_aux(Y,P1),X\=Y.")
predicates.append("plot1_aux(X,P1) :- plot_keyword(X,P1).")
predicates.append("plot2(X,Y) :- plot2_aux(X,P1,P2),plot2_aux(Y,P1,P2),X\=Y.")
predicates.append("plot2_aux(X,P1,P2) :- plot_keyword(X,P1),plot_keyword(X,P2),P1@<P2.")
predicates.append("plot3_aux(X,P1,P2,P3) :- plot_keyword(X,P1),plot_keyword(X,P2),plot_keyword(X,P3),P1@<P2,P2@<P3.")
predicates.append("plot3(X,Y) :- plot3_aux(X,P1,P2,P3),plot3_aux(Y,P1,P2,P3),X\=Y.")
predicates.append("plot4(X,Y) :- plot4_aux(X,P1,P2,P3,P4),plot4_aux(Y,P1,P2,P3,P4),X\=Y.")
predicates.append("plot4_aux(X,P1,P2,P3,P4) :- plot_keyword(X,P1),plot_keyword(X,P2),plot_keyword(X,P3),plot_keyword(X,P4),P1@<P2,P2@<P3,P3@<P4.")
predicates.append("plot5_aux(X,P1,P2,P3,P4,P5) :- plot_keyword(X,P1),plot_keyword(X,P2),plot_keyword(X,P3),plot_keyword(X,P4),plot_keyword(X,P5),P1@<P2,P2@<P3,P3@<P4,P4@<P5.")
predicates.append("plot5(X,Y) :- plot5_aux(X,P1,P2,P3,P4,P5),plot5_aux(Y,P1,P2,P3,P4,P5),X\=Y.")
predicates.append("plot7_aux(X,P1,P2,P3,P4,P5,P6,P7) :- plot_keyword(X,P1),plot_keyword(X,P2),plot_keyword(X,P3),plot_keyword(X,P4),plot_keyword(X,P5),plot_keyword(X,P6),plot_keyword(X,P7),P1@<P2,P2@<P3,P3@<P4,P4@<P5,P5@<P6,P6@<P7.")
predicates.append("plot7(X,Y) :- plot7_aux(X,P1,P2,P3,P4,P5,P6,P7),plot7_aux(Y,P1,P2,P3,P4,P5,P6,P7),X\=Y.")

predicates.append("actor1_aux(X,A1) :- actor(X,A1).")
predicates.append("actor1(X,Y) :- actor1_aux(X,A1),actor1_aux(Y,A1),X\=Y.")
predicates.append("actor2_aux(X,A1,A2) :- actor(X,A1),actor(X,A2),A1@<A2.")
predicates.append("actor2(X,Y) :- actor2_aux(X,A1,A2),actor2_aux(Y,A1,A2),X\=Y.")
predicates.append("actor3_aux(X,A1,A2,A3) :- actor(X,A1),actor(X,A2),actor(X,A3),A1@<A2,A2@<A3.")
predicates.append("actor3(X,Y) :- actor3_aux(X,A1,A2,A3),actor3_aux(Y,A1,A2,A3),X\=Y.")

predicates.append("same_language(X,Y) :- spoken_language(X,L1),spoken_language(Y,L1),X\=Y.")
predicates.append("same_language_not_en(X,Y) :- spoken_language(X,L1),spoken_language(Y,L1),X\=Y,L1\='en'.")

predicates.append("black_and_white(X) :- plot_keyword(X,'black and white').")

#predicates.append("prod_company(X,A1) :- prod_company(X,A1).")
predicates.append("prod_company(X,Y) :- prod_company(X,A1),prod_company(Y,A1),X\=Y.")

predicates.append("country(X,A1) :- country(X,A1).")
predicates.append("same_country(X,Y) :- country(X,A1),country(Y,A1).")

#predicates.append("year(X,A1).mod(100).div(10) :- year(Y,A1).mod(100).div(10)")

predicates.append("decade(X,A1) :- decade(X,A1).")
predicates.append("same_decade(X,Y) :- decade(X,A1),decade(Y,A1),X\=Y.")

predicates.sort()

f = open("world.pl", "a")
for predicate in predicates:
    f.write(predicate + "\n")
f.close()

# Κάνουμε consult ένα έτοιμο αρχείο στον κόσμο μας
prolog.consult("world.pl")

# %%
#q = prolog.query("same_decade('Avatar',Y).")
#s = set()
#for soln in q:
#    s.add(soln['Y'])
#print(s)
#print(len(s))

# %% [markdown]
# # **2ο Μέρος: Recommendation System με βάση μόνο τα χαρακτηριστικά των ταινιών.**
#
# Στο σημείο αυτό με βάση τους κανόνες που κατασκευάστηκαν στο Μέρος 1 θα κατασκευαστούν κατηγορήματα για την ομοιότητα ταινιών. Παρακάτω δίνεται ένα μικρό παράδειγμα ενός κανόνα και πώς αυτός θα μπορούσε να γραφτεί μέσω του Pyswip. Επίσης όπως αναφέρεται και σε σχόλιο παραπάνω θα μπορεί να γραφτεί και μια βάση δεδομένων με τους κανόνες και να γίνει απευθείας consult.
#
# Στο παρακάτω παράδειγμα το 5 και το 4 εκφράζουν την ομοιότητα των ταινιών π.χ. οι ταινίες που παράγονται μέσω του find_similar_5 είναι πιο όμοιες από αυτές που παράγονται μέσω του find_similar_4.

# %%
f = open("world.pl", "a")

#f.write('''find_sim1(X,Y):- genre4(X,Y), X \= Y. '''+ "\n")
#find_sim2(X,Y) :- vote_avg(X,M), vote_avg(Y,M2), abs(M-M2) =< 2, X \= Y.
#atom_number: predicate to convert atoms to integers so that we can use them in calculation
# f.write('''find_sim0(X,Y):- common_director(X,Y).
#                 ''' + "\n")

#Checks if they have at least 2 common genres and similar plot but taking in account the number of keywords a movie has
f.write('''find_sim1(X,Y):- plot_keywords_no(X,PLK1),atom_number(PLK1,PLK1ATM),plot_keywords_no(Y,PLK2),atom_number(PLK2,PLK2ATM),
            (
                    (
                        ( PLK1ATM>20 -> plot2(X,Y)
                        ; PLK1ATM>3 -> plot1(X,Y))
                        ;
                        ( PLK2ATM>20 -> plot2(Y,X)
                        ; PLK2ATM>3 -> plot1(Y,X))
                    )
                ;
                    (
                        genre2(X,Y)
                    )
                ).
                ''' + "\n")


#Checks how many genres each move has and how many plot keywords, if the movie has more than 15 keywords it finds the movies with plot similarity level 2
#if it has more than 2 it finds the movies with plot similarity level 1
#similarly it finds the no of genres a movie has and if the genres are more than four it finds the movie with 2 common genres
#and accordingly if it has more than 1 it finds the movie with 1 common genre
f.write('''find_sim2(X,Y):-  genre_no(X,G1),atom_number(G1,G1ATM),genre_no(Y,G2),atom_number(G2,G2ATM),plot_keywords_no(X,PLK1),atom_number(PLK1,PLK1ATM),plot_keywords_no(Y,PLK2),atom_number(PLK2,PLK2ATM),
            (
                ( PLK1ATM>15 -> plot2(X,Y)
                ; PLK1ATM>3 -> plot1(X,Y)
                ; true)
                ;
                ( PLK2ATM>15 -> plot2(Y,X)
                ; PLK2ATM>3 -> plot1(Y,X)
                ; true)
            ),
            (
                ( G1ATM>=4 -> genre2(X,Y)
                ; G1ATM>=1 -> genre1(X,Y))
                ;
                ( G2ATM>=4 -> genre2(Y,X)
                ; G2ATM>=1 -> genre1(Y,X))
            )
            .''' + "\n")

#Checks if the two movies have 2 common numbers and rating difference less than 2
f.write('''find_sim3(X,Y):- genre3(X,Y),vote_avg(X,M1),atom_number(M1,ATM1),vote_avg(Y,M2),atom_number(M2,ATM2),abs(ATM1-ATM2)=< 2.0,X \= Y.\n''')

#movies have the same language,common director and based on the number of genres they have , they must have either 2 common genres or 1
f.write('''find_sim4(X,Y) :- same_language(X,Y),genre_no(X,G1), atom_number(G1,G1ATM),genre_no(Y,G2), atom_number(G2,G2ATM),
  (
    (G1ATM >= 4 -> genre2(X,Y)
    ; G1ATM >= 1 -> genre1(X,Y)),
    (G2ATM >= 4 -> genre2(Y,X)
    ; G2ATM >= 1 -> genre1(Y,X))
  ),
  (
    actor1(X,Y)
  )
  .''' + "\n")

#movies have the same language,one common actor , based on the number of genres they have , they must have either 2 common genres or 1 and based on the number of keywords they have , they must have either level 2 or 1 common plot

f.write('''find_sim5(X,Y) :- same_language(X,Y),genre_no(X,G1), atom_number(G1,G1ATM),genre_no(Y,G2), atom_number(G2,G2ATM),plot_keywords_no(X,PLK1),atom_number(PLK1,PLK1ATM),plot_keywords_no(Y,PLK2),atom_number(PLK2,PLK2ATM),
          (
                ( PLK1ATM>15 -> plot2(X,Y)
                ; PLK1ATM>3 -> plot1(X,Y)
                ; true)
                ;
                ( PLK2ATM>15 -> plot2(Y,X)
                ; PLK2ATM>3 -> plot1(Y,X)
                ; true)
            ),
          (
            (G1ATM >= 4 -> genre2(X,Y)
            ; G1ATM >= 1 -> genre1(X,Y)),
            (G2ATM >= 4 -> genre2(Y,X)
          ; G2ATM >= 1 -> genre1(Y,X))
          ),
        (
            actor1(X,Y)
          )
          .''' + "\n")

# #Movies have the same language, then based on the no of genres each movie has call the predicate for common genres either 1 or 2
# #movies must have at least two common actors or one common actor and common director
# f.write('''find_sim6(X,Y):- same_language(X,Y),genre_no(X,G1),atom_number(G1,G1ATM),genre_no(Y,G2),atom_number(G2,G2ATM),
#           (
#                 ( G1ATM>=4 -> genre2(X,Y)
#                 ; G1ATM>=1 -> genre1(X,Y))
#                 ;
#                 ( G2ATM>=4 -> genre2(Y,X)
#                 ; G2ATM>=1 -> genre1(Y,X))
#           ),
#               (   actor1(X,Y),common_director(X,Y) ; actor2(X,Y)
#             )
#             .''' + "\n")

#The movie with the least genres must have all the same ones as the other movie, and either a common director and one actor or two common OR one common actor or common director and similar plot
f.write('''find_sim6(X,Y):- same_language(X,Y),genre_no(X,G1),atom_number(G1,G1ATM),genre_no(Y,G2),atom_number(G2,G2ATM),plot_keywords_no(X,PLK1),atom_number(PLK1,PLK1ATM),plot_keywords_no(Y,PLK2),atom_number(PLK2,PLK2ATM),
          (
                ( G1ATM>=4 -> genre4(X,Y)
                ; G1ATM==3 -> genre3(X,Y)
                ; G1ATM==2 -> genre2(X,Y)
                ; G1ATM==1 -> genre1(X,Y)
                )
                ;
                ( G2ATM>=4 -> genre4(Y,X)
                ; G2ATM==3 -> genre3(Y,X)
                ; G2ATM==2 -> genre2(Y,X)
                ; G2ATM==1 -> genre1(Y,X)
                )
          ),
          (
              (
                ( actor1(X,Y),common_director(X,Y)) ; actor2(X,Y)
              )
            ;
              (
                (actor1(X,Y); common_director(X,Y)),
                (
                  ( PLK1ATM>15 -> plot2(X,Y)
                  ; PLK1ATM>15 -> plot4(X,Y)
                  ; PLK1ATM>10 -> plot3(X,Y)
                  ; PLK1ATM>7 -> plot2(X,Y)
                  ; PLK1ATM>3 -> plot1(X,Y)
                  ; true
                  )
                  ;
                  ( PLK2ATM>15 -> plot4(Y,X)
                  ; PLK2ATM>10 -> plot3(Y,X)
                  ; PLK2ATM>7 -> plot2(Y,X)
                  ; PLK2ATM>3 -> plot1(Y,X)
                  ; true)
              )
            )

            ).''' + "\n")


f.write('''find_sim7(X,Y):- same_language(X,Y),genre_no(X,G1),atom_number(G1,G1ATM),genre_no(Y,G2),atom_number(G2,G2ATM),plot_keywords_no(X,PLK1),atom_number(PLK1,PLK1ATM),plot_keywords_no(Y,PLK2),atom_number(PLK2,PLK2ATM),
          (
                ( G1ATM>=4 -> genre4(X,Y)
                ; G1ATM==3 -> genre3(X,Y)
                ; G1ATM==2 -> genre2(X,Y)
                ; G1ATM==1 -> genre1(X,Y)
                )
                ;
                ( G2ATM>=4 -> genre4(Y,X)
                ; G2ATM==3 -> genre3(Y,X)
                ; G2ATM==2 -> genre2(Y,X)
                ; G2ATM==1 -> genre1(Y,X)
                )
          ),
          (
              (
                ( actor2(X,Y),common_director(X,Y)) ; actor3(X,Y)
              )
            ;
              (
                ((actor1(X,Y), common_director(X,Y)); actor2(X,Y)),
                (
                  ( PLK1ATM>15 -> plot2(X,Y)
                  ; PLK1ATM>15 -> plot4(X,Y)
                  ; PLK1ATM>10 -> plot3(X,Y)
                  ; PLK1ATM>7 -> plot2(X,Y)
                  ; PLK1ATM>3 -> plot1(X,Y)
                  ; true
                  )
                  ;
                  ( PLK2ATM>15 -> plot4(Y,X)
                  ; PLK2ATM>10 -> plot3(Y,X)
                  ; PLK2ATM>7 -> plot2(Y,X)
                  ; PLK2ATM>3 -> plot1(Y,X)
                  ; true)
              )
            )

            ).''' + "\n")

f.close()
prolog.consult("world.pl")

q1 = prolog.query("find_sim1('Avatar', Y)")
s1 = set()
for soln in q1:
  s1.add(soln['Y'])
print("Find_sim1=", s1)
print(len(s1))

q2 = prolog.query("find_sim2('Avatar', Y)")
s2 = set()
for soln in q2:
  s2.add(soln['Y'])
print("Find_sim2=" , s2)
print(len(s2))

q3 = prolog.query("find_sim3('Avatar', Y)")
s3 = set()
for soln in q3:
  s3.add(soln['Y'])
print("Find_sim3=" , s3)
print(len(s3))

q4 = prolog.query("find_sim4('Avatar', Y)")
s4 = set()
for soln in q4:
  s4.add(soln['Y'])
print("Find_sim4=" , s4)
print(len(s4))

q5 = prolog.query("find_sim5('Avatar', Y)")
s5 = set()
for soln in q5:
  s5.add(soln['Y'])
print("Find_sim5=" , s5)
print(len(s5))

q6 = prolog.query("find_sim6('Avatar', Y)")
s6 = set()
for soln in q6:
  s6.add(soln['Y'])
print("Find_sim6=" , s6)
print(len(s6))

q7 = prolog.query("find_sim7('Avatar', Y)")
s7 = set()
for soln in q7:
  s7.add(soln['Y'])
print("Find_sim7=" , s7)
print(len(s7))

# q8 = prolog.query("find_sim8('Avatar', Y)")
# s8 = set()
# for soln in q8:
#   s8.add(soln['Y'])
# print("Find_sim8=" , s8)
# print(len(s8))

# q0 = prolog.query("find_sim0('Avatar', Y)")
# s0 = set()
# for soln in q0:
#   s0.add(soln['Y'])
# print("Find_sim0=" , s0)
# print(len(s0))
# Out:
# Find_sim1= {'The Sorcerers Apprentice', 'Kate & Leopold', 'Superhero Movie', 'Mad Max', 'MacGruber', 'Rise of the Planet of the Apes', 'One for the Money', 'Star Trek: First Contact', 'Petes Dragon', 'Die Another Day', 'The Adventurer: The Curse of the Midas Box', 'Independence Day: Resurgence', 'Wild Wild West', 'Cirque du Freak: The Vampires Assistant', 'Firestarter', 'Moon', 'The Mask of Zorro', 'The Musketeer', 'Robin and Marian', 'The Peanuts Movie', 'Thunderball', 'I, Frankenstein', 'In the Shadow of the Moon', 'Back to the Future Part II', 'Titanic', 'Jackass 3D', 'Jumper', 'Men in Black II', 'Yogi Bear', 'The Thin Red Line', 'Clash of the Titans', 'Apollo 18', 'The 5th Wave', 'Abraham Lincoln: Vampire Hunter', 'Inkheart', 'Sherlock Holmes: A Game of Shadows', 'Subway', 'The Hunger Games: Mockingjay - Part 2', 'Maleficent', 'Bend It Like Beckham', 'Diamonds Are Forever', 'Resident Evil: Afterlife', 'Mission: Impossible - Ghost Protocol', 'Thunderbirds', 'Apocalypse Now', 'Equilibrium', 'Happily NEver After', 'The Spiderwick Chronicles', 'The Wraith', 'The Core', 'Transformers: Revenge of the Fallen', 'GoldenEye', 'Ronin', 'My Stepmother is an Alien', 'Midnight Special', 'The Hunger Games', 'The Thing', 'The Maze Runner', 'Johnny English Reborn', 'Terminator Genisys', 'American Desi', 'Nothing to Lose', 'Timecop', 'Escape from New York', 'The One', 'Elysium', '1911', 'Anna and the King', 'Bicentennial Man', 'Octopussy', 'G.I. Joe: Retaliation', 'Night at the Museum: Battle of the Smithsonian', 'Memoirs of an Invisible Man', 'Alien Zone', 'The Imaginarium of Doctor Parnassus', 'Alice in Wonderland', 'Street Fighter: The Legend of Chun-Li', 'Fetching Cody', 'Cloverfield', 'Muppets from Space', 'Space Cowboys', 'Spawn', 'G.I. Jane', 'The Golden Compass', 'The Amazing Spider-Man', 'Waterworld', 'Moonraker', 'The Hunger Games: Mockingjay - Part 1', 'Red Planet', 'Sex Drive', 'Without a Paddle', 'Iron Man 2', 'Spaceballs', 'Virtuosity', 'Batman & Robin', 'Jurassic Park III', 'Wag the Dog', 'Pirates of the Caribbean: The Curse of the Black Pearl', 'Young Guns', 'Your Sisters Sister', 'Stardust', 'K-PAX', 'Ironclad', 'Hollow Man', 'Piranha 3D', 'The Warriors Way', 'Legend of a Rabbit', 'Falcon Rising', 'The Martian', 'The Crying Game', 'Universal Soldier: The Return', 'Teenage Mutant Ninja Turtles II: The Secret of the Ooze', 'Touching the Void', 'Shanghai Knights', 'Becoming Jane', 'Transformers: Age of Extinction', 'Gamer', 'Percy Jackson & the Olympians: The Lightning Thief', 'TRON: Legacy', 'Dragon Blade', 'The Phantom', 'Dark City', 'The Expendables 3', 'Jack the Giant Slayer', 'Speed Racer', 'Noah', 'Back to the Future Part III', 'Switchback', 'The Spirit', 'The Four Feathers', 'Spider-Man', 'Star Trek Into Darkness', 'CJ7', 'Stormbreaker', 'The Last Legion', 'The Island of Dr. Moreau', 'A Lonely Place to Die', 'My Soul to Take', 'My Bloody Valentine', 'Everest', 'Arthur and the Invisibles', 'Batman Returns', 'Idiocracy', 'The Croods', 'Impostor', 'Signs', 'Lucky Numbers', 'Ishtar', 'The Book of Eli', 'Deep Rising', '2046', 'Battle for the Planet of the Apes', 'Jonah Hex', 'RoboCop 3', 'Skyline', 'Mutual Appreciation', 'Supercross', 'Batman', 'The Forsaken', 'Battle: Los Angeles', 'Journey to the Center of the Earth', 'The Great Raid', 'John Carter', 'In Time', 'Austin Powers: The Spy Who Shagged Me', 'The Box', 'Phenomenon', 'Virgin Territory', 'House of Flying Daggers', 'Return to Oz', 'Nims Island', 'Shanghai Noon', 'Soldier', 'Elektra', 'Night at the Museum', 'Flyboys', 'Cellular', 'Poseidon', 'The Fugitive', 'Mighty Joe Young', 'Steel', 'Daybreakers', 'Six-String Samurai', 'The Nutty Professor', 'The Count of Monte Cristo', 'Wing Commander', 'The League of Extraordinary Gentlemen', 'Osmosis Jones', 'Passchendaele', 'Skyfall', 'The Sticky Fingers of Time', 'Casino Royale', 'Love Letters', 'Transformers', 'Big Trouble in Little China', 'Rambo III', 'Chappie', 'The Devils Tomb', 'Silent Hill: Revelation 3D', 'Batman: The ...
# 975
# Find_sim2= {'Nomad: The Warrior', 'MacGruber', 'Southpaw', 'One for the Money', 'Independence Day: Resurgence', 'Moon', 'The Snow Queen', 'Khiladi 786', 'Jackass 3D', 'Men in Black II', 'Clash of the Titans', 'Apollo 18', 'The 5th Wave', 'Abraham Lincoln: Vampire Hunter', 'The Hunger Games: Mockingjay - Part 2', 'Sherlock Holmes: A Game of Shadows', 'Subway', 'Maleficent', 'Resident Evil: Afterlife', 'American Heist', 'The Core', 'Limbo', 'My Stepmother is an Alien', 'The Thing', 'Terminator Genisys', 'The One', 'Elysium', 'Bicentennial Man', 'G.I. Joe: Retaliation', 'Memoirs of an Invisible Man', 'Alien Zone', 'Alice in Wonderland', 'Man of the House', 'Out of Inferno', 'The Ghastly Love of Johnny X', 'Fetching Cody', 'Muppets from Space', 'Space Cowboys', 'Moonraker', 'Red Planet', 'Without a Paddle', 'Only the Strong', 'Legend of a Rabbit', 'Falcon Rising', 'The Martian', 'Transformers: Age of Extinction', 'Dragon Blade', 'Dark City', 'The Expendables 3', 'Jack the Giant Slayer', 'Noah', 'Switchback', 'Star Trek Into Darkness', 'CJ7', 'Ladder 49', 'Max Payne', 'Everest', 'Valiant', 'Impostor', 'Skyline', 'Battle for the Planet of the Apes', 'Supercross', 'Battle: Los Angeles', 'Journey to the Center of the Earth', 'Sugar Hill', 'Triple 9', 'The Great Raid', 'John Carter', 'In Time', 'London', 'Virgin Territory', 'Return to Oz', 'Soldier', 'Flyboys', 'Pound of Flesh', 'Mighty Joe Young', 'Steel', 'Zoom', 'Six-String Samurai', 'Silmido', 'The Nutty Professor', 'The Sticky Fingers of Time', 'Transformers', 'Wolves', 'Parker', 'Batman: The Dark Knight Returns, Part 2', 'Bait', 'A Monster in Paris', 'I Origins', 'Down to Earth', 'Jane Got a Gun', 'Somewhere in Time', 'G-Force', 'The Sentinel', 'Silver Medalist', 'The Bounty Hunter', 'Super 8', 'The Legend of Hells Gate: An American Conspiracy', 'Invasion U.S.A.', 'Brooklyn Rules', 'The Stepford Wives', 'Force 10 from Navarone', 'The Beastmaster', 'Extreme Ops', 'Total Recall', 'Reign of Assassins', 'Made', 'The Muse', 'The Newton Boys', 'Unleashed', 'The Thief and the Cobbler', 'Stealth', 'American Ninja 2: The Confrontation', 'Area 51', 'Catch That Kid', 'Down Terrace', 'Son of the Mask', 'Captain America: The First Avenger', 'Cypher', 'The Jackal', 'Madison', 'Rapa Nui', 'The Lost Medallion: The Adventures of Billy Stone', 'Hit & Run', 'Six Days Seven Nights', 'Hercules', 'Corky Romano', 'Troop Beverly Hills', 'Creature', 'Hereafter', 'Heroes of Dirt', 'Queen Crab', 'The Barbarians', 'Shadow Conspiracy', 'Slither', 'Crazy Stone', 'Once Upon a Time in Mexico', 'The November Man', 'War, Inc.', 'The Hitchhikers Guide to the Galaxy', 'Invaders from Mars', 'Prometheus', 'The Legend of Gods Gun', 'Silent Trigger', 'Savva. Heart of the Warrior', 'The 6th Day', 'Warlock: The Armageddon', 'Echo Dr.', 'The Good, The Bad, The Weird', 'Wicked Blood', 'Atlas Shrugged Part III: Who is John Galt?', 'Ultramarines: A Warhammer 40,000 Movie', 'Race to Witch Mountain', 'Tracker', 'Percy Jackson: Sea of Monsters', 'Enders Game', 'Predator', 'Thor: The Dark World', 'Three Kingdoms: Resurrection of the Dragon', 'Days of Thunder', 'Dragon Nest: Warriors Dawn', 'The Nutcracker: The Untold Story', 'Miss Congeniality', 'Aliens in the Attic', 'DragonHeart', 'Aliens vs Predator: Requiem', 'Green Zone', 'Pompeii', 'Alice Through the Looking Glass', 'The Three Musketeers', 'Galaxina', 'Krrish', 'Astro Boy', 'The Monkey King 2', 'The Mummy Returns', 'War', 'All Superheroes Must Die', 'Ong Bak 2', 'Inspector Gadget', 'Insurgent', 'Bronson', 'The Hole', 'Lockout', 'Shanghai Surprise', 'Unstoppable', 'Kiss of the Dragon', 'Jason Bourne', 'Source Code', 'Last Holiday', 'Mars Needs Moms', 'Goosebumps', 'Ip Man 3', 'The Purge: Election Year', 'Unsullied', 'Saving Private Perez', 'Planet 51', 'Shade', 'Swelter', 'Black Rain', 'Tora! Tora! Tora!', 'The Adventures of Sharkboy and Lavagirl', 'Planet of the Apes', 'Independence Day', 'Platoon', 'Treasure Planet', 'Underworld: Rise of the Lycans', 'Final Fantasy: The S ...
# 502
# Find_sim3= {'The Sorcerers Apprentice', 'The Thief and the Cobbler', 'Reign of Fire', 'The Shadow', 'Star Wars: Clone Wars: Volume 1', 'Mad Max', 'I Am Number Four', 'The Island', 'Delgo', 'Superman III', 'Star Trek: First Contact', 'Hellboy II: The Golden Army', 'Zathura: A Space Adventure', 'Captain America: The First Avenger', 'The Black Hole', 'Cirque du Freak: The Vampires Assistant', 'The Fifth Element', 'Conan the Destroyer', 'Star Wars', 'The Hobbit: An Unexpected Journey', 'The Mummy: Tomb of the Dragon Emperor', 'Star Trek III: The Search for Spock', 'Jumper', 'Men in Black II', 'Titan A.E.', 'Krull', 'Clash of the Titans', 'X-Men Origins: Wolverine', 'The Empire Strikes Back', 'Small Soldiers', 'Spider-Man 3', 'The 13th Warrior', 'The Hunger Games: Mockingjay - Part 2', 'Transformers: Dark of the Moon', 'Maleficent', 'Resident Evil: Afterlife', '47 Ronin', 'The Hunger Games: Catching Fire', 'Transformers: Revenge of the Fallen', 'Bill & Teds Bogus Journey', 'The Lord of the Rings: The Return of the King', 'Avengers: Age of Ultron', 'Pacific Rim', 'The Core', 'Superman II', 'The Matrix Reloaded', 'Southland Tales', 'Serenity', 'Star Wars: Episode II - Attack of the Clones', 'The Hunger Games', 'Inception', 'Shin Godzilla', 'Last Action Hero', 'Paycheck', 'Terminator Genisys', 'Logans Run', 'The Last Witch Hunter', 'The Hobbit: The Battle of the Five Armies', 'X-Men: First Class', 'The Wolverine', 'Lara Croft Tomb Raider: The Cradle of Life', 'Night at the Museum: Battle of the Smithsonian', 'G.I. Joe: Retaliation', 'X2', 'Oblivion', 'Tank Girl', 'Race to Witch Mountain', 'The Forbidden Kingdom', 'Puss in Boots', 'The Amazing Spider-Man', 'Jurassic World', 'Moonraker', 'Man of Steel', 'Captain America: The Winter Soldier', 'Enders Game', 'Predator', 'Thor: The Dark World', 'Underworld: Evolution', 'Teenage Mutant Ninja Turtles: Out of the Shadows', 'Iron Man 2', 'Predators', 'Pirates of the Caribbean: Dead Mans Chest', 'Jurassic Park III', 'Mad Max Beyond Thunderdome', 'Pirates of the Caribbean: The Curse of the Black Pearl', 'Aliens in the Attic', 'The Lord of the Rings: The Fellowship of the Ring', 'Highlander', 'X-Men: Days of Future Past', 'The Brothers Grimm', 'The Warriors Way', 'X-Men', 'Jupiter Ascending', 'Journey 2: The Mysterious Island', 'Teenage Mutant Ninja Turtles II: The Secret of the Ooze', 'The Inhabited Island', 'Spider-Man 2', 'Jonah: A VeggieTales Movie', 'Transformers: Age of Extinction', 'Ant-Man', 'The Borrowers', 'TRON: Legacy', 'The Covenant', 'Star Trek Into Darkness', 'Star Trek: Generations', 'Teenage Mutant Ninja Turtles', 'Iron Man 3', 'The Monkey King 2', 'Babylon A.D.', 'Captain America: Civil War', 'The Scorpion King', 'Star Trek Beyond', 'The Mummy Returns', 'Firefox', 'Timeline', 'The Lost World: Jurassic Park', 'Star Trek II: The Wrath of Khan', 'The Host', 'The Matrix Revolutions', 'Superman Returns', 'Prince of Persia: The Sands of Time', 'Deep Rising', 'Mad Max: Fury Road', 'Time Bandits', 'Batman', 'Journey to the Center of the Earth', 'John Carter', 'Pokémon: Spell of the Unknown', 'The Lord of the Rings: The Two Towers', 'G.I. Joe: The Rise of Cobra', 'E.T. the Extra-Terrestrial', 'Superman', 'Iron Man', 'Mystery Men', 'Star Wars: Episode I - The Phantom Menace', 'Sky Captain and the World of Tomorrow', 'Night at the Museum', 'Pirates of the Caribbean: On Stranger Tides', 'Star Wars: Episode III - Revenge of the Sith', 'Suicide Squad', '2012', 'The Day After Tomorrow', 'Pirates of the Caribbean: At Worlds End', 'Escape from L.A.', 'The Incredible Hulk', 'Planet of the Apes', 'Independence Day', 'Mighty Joe Young', 'Batman v Superman: Dawn of Justice', 'The Mortal Instruments: City of Bones', 'Treasure Planet', 'Underworld: Rise of the Lycans', 'Daybreakers', 'Six-String Samurai', 'The League of Extraordinary Gentlemen', 'Final Fantasy: The Spirits Within', 'Men in Black', 'Godzilla 2000', 'Blade: Trinity', 'Brave', 'Transformers', 'Priest', 'Big Trouble in Little China', 'The ...
# 197
# Find_sim4= {'The Losers', 'Crossroads', 'Star Trek Into Darkness', 'Guardians of the Galaxy', 'The Book of Life', 'Alien'}
# 6
# Find_sim5= {'Star Trek Into Darkness', 'Guardians of the Galaxy', 'Alien'}
# 3
# Find_sim6= {'Star Trek Into Darkness'}
# 1
# Find_sim7= set()
# 0
# Find_sim0= {'True Lies', 'Aliens', 'The Terminator', 'Terminator 2: Judgment Day', 'Titanic', 'The Abyss'}
# 6

# %%
def simple_recommender(movie,sim_level):
    s = set()
    q = prolog.query("find_sim" + str(sim_level) + "('" + movie + "',M)")
    for soln in q:
        s.add(soln['M'])
    q.close()
    answers = s
    return answers

# %%
list(simple_recommender('Avatar', 5))[:5]
# Out:
# ['Star Trek Into Darkness', 'Guardians of the Galaxy', 'Alien']

# %%
q1 = prolog.query("find_sim1('Avatar', Y)")
s1 = set()
for soln in q1:
  s1.add(soln['Y'])
print(s1)
print(len(s1))
# Out:
# {'The Sorcerers Apprentice', 'Kate & Leopold', 'Superhero Movie', 'Mad Max', 'MacGruber', 'Rise of the Planet of the Apes', 'One for the Money', 'Star Trek: First Contact', 'Petes Dragon', 'Die Another Day', 'The Adventurer: The Curse of the Midas Box', 'Independence Day: Resurgence', 'Wild Wild West', 'Cirque du Freak: The Vampires Assistant', 'Firestarter', 'Moon', 'The Mask of Zorro', 'The Musketeer', 'Robin and Marian', 'The Peanuts Movie', 'Thunderball', 'I, Frankenstein', 'In the Shadow of the Moon', 'Back to the Future Part II', 'Titanic', 'Jackass 3D', 'Jumper', 'Men in Black II', 'Yogi Bear', 'The Thin Red Line', 'Clash of the Titans', 'Apollo 18', 'The 5th Wave', 'Abraham Lincoln: Vampire Hunter', 'Inkheart', 'Sherlock Holmes: A Game of Shadows', 'Subway', 'The Hunger Games: Mockingjay - Part 2', 'Maleficent', 'Bend It Like Beckham', 'Diamonds Are Forever', 'Resident Evil: Afterlife', 'Mission: Impossible - Ghost Protocol', 'Thunderbirds', 'Apocalypse Now', 'Equilibrium', 'Happily NEver After', 'The Spiderwick Chronicles', 'The Wraith', 'The Core', 'Transformers: Revenge of the Fallen', 'GoldenEye', 'Ronin', 'My Stepmother is an Alien', 'Midnight Special', 'The Hunger Games', 'The Thing', 'The Maze Runner', 'Johnny English Reborn', 'Terminator Genisys', 'American Desi', 'Nothing to Lose', 'Timecop', 'Escape from New York', 'The One', 'Elysium', '1911', 'Anna and the King', 'Bicentennial Man', 'Octopussy', 'G.I. Joe: Retaliation', 'Night at the Museum: Battle of the Smithsonian', 'Memoirs of an Invisible Man', 'Alien Zone', 'The Imaginarium of Doctor Parnassus', 'Alice in Wonderland', 'Street Fighter: The Legend of Chun-Li', 'Fetching Cody', 'Cloverfield', 'Muppets from Space', 'Space Cowboys', 'Spawn', 'G.I. Jane', 'The Golden Compass', 'The Amazing Spider-Man', 'Waterworld', 'Moonraker', 'The Hunger Games: Mockingjay - Part 1', 'Red Planet', 'Sex Drive', 'Without a Paddle', 'Iron Man 2', 'Spaceballs', 'Virtuosity', 'Batman & Robin', 'Jurassic Park III', 'Wag the Dog', 'Pirates of the Caribbean: The Curse of the Black Pearl', 'Young Guns', 'Your Sisters Sister', 'Stardust', 'K-PAX', 'Ironclad', 'Hollow Man', 'Piranha 3D', 'The Warriors Way', 'Legend of a Rabbit', 'Falcon Rising', 'The Martian', 'The Crying Game', 'Universal Soldier: The Return', 'Teenage Mutant Ninja Turtles II: The Secret of the Ooze', 'Touching the Void', 'Shanghai Knights', 'Becoming Jane', 'Transformers: Age of Extinction', 'Gamer', 'Percy Jackson & the Olympians: The Lightning Thief', 'TRON: Legacy', 'Dragon Blade', 'The Phantom', 'Dark City', 'The Expendables 3', 'Jack the Giant Slayer', 'Speed Racer', 'Noah', 'Back to the Future Part III', 'Switchback', 'The Spirit', 'The Four Feathers', 'Spider-Man', 'Star Trek Into Darkness', 'CJ7', 'Stormbreaker', 'The Last Legion', 'The Island of Dr. Moreau', 'A Lonely Place to Die', 'My Soul to Take', 'My Bloody Valentine', 'Everest', 'Arthur and the Invisibles', 'Batman Returns', 'Idiocracy', 'The Croods', 'Impostor', 'Signs', 'Lucky Numbers', 'Ishtar', 'The Book of Eli', 'Deep Rising', '2046', 'Battle for the Planet of the Apes', 'Jonah Hex', 'RoboCop 3', 'Skyline', 'Mutual Appreciation', 'Supercross', 'Batman', 'The Forsaken', 'Battle: Los Angeles', 'Journey to the Center of the Earth', 'The Great Raid', 'John Carter', 'In Time', 'Austin Powers: The Spy Who Shagged Me', 'The Box', 'Phenomenon', 'Virgin Territory', 'House of Flying Daggers', 'Return to Oz', 'Nims Island', 'Shanghai Noon', 'Soldier', 'Elektra', 'Night at the Museum', 'Flyboys', 'Cellular', 'Poseidon', 'The Fugitive', 'Mighty Joe Young', 'Steel', 'Daybreakers', 'Six-String Samurai', 'The Nutty Professor', 'The Count of Monte Cristo', 'Wing Commander', 'The League of Extraordinary Gentlemen', 'Osmosis Jones', 'Passchendaele', 'Skyfall', 'The Sticky Fingers of Time', 'Casino Royale', 'Love Letters', 'Transformers', 'Big Trouble in Little China', 'Rambo III', 'Chappie', 'The Devils Tomb', 'Silent Hill: Revelation 3D', 'Batman: The Dark Knigh ...
# 975

# %% [markdown]
# # **3ο Μέρος: Recommendation System Με βάση τις προτιμήσεις-Αξιολογήσεις του χρήστη-Εκπαίδευση και Πρόβλεψη**
#
#
# Αρχικά μελετάμε τις αξιολογήσεις κάθε χρήστη για να καταλάβουμε την δομή και τις πληροφορίες κάθε αρχείου.

# %%
from tqdm.notebook import tqdm
from sklearn.metrics import precision_score, recall_score, f1_score
from termcolor import colored
rating_weights = {0: -1, 1: -0.5, 2:0, 3:0, 4:0.5, 5:1}
score_weights = {1: 0.05, 2:0.2, 3:1, 4:2, 5:3, 6:5, 7:10} # ανάλογα με τα επίπεδα ομοιότητας που έχουν οριστεί στην simple_recommender

directors = {}
actors = {}
gen = {}

def train_recommender(ratings, rating_weights, score_weights, start=0, end = -1, movie_score = {}):

    """
    Στην συνάρτηση αυτή μπορούμε να ορίζουμε ποιο υποσύνολο των αξιολογήσεων θα χρησιμοποιήσουμε για το train,
    ενώ παράλληλα μπορούμε να αρχικοποιήσουμε και το movie_score το οποίο αποθηκεύονται τα score κάθε ταινίας.
    Έτσι αν έχουμε κάνει train τον recommender μας για τις πρώτες 10 ταινίες, μπορούμε να συνεχίσουμε για τις
    υπόλοιπες χωρίς κάθε φορά να ξανά-διαμορφώνουμε το score για αυτές. Αυτό θα σας βοηθήσει στην εκτέλεση και χρονικά όταν ελέγχετε την
    απόδοση σε υποσύνολα των ratings π.χ. πρώτες 10 ταινίες έπειτα τις επόμενες 20 κ.ο.κ.
    """
    if end == -1:
        end = len(ratings)

    ratings = ratings.iloc[range(start, end)]
    for row in tqdm(ratings.itertuples(index = True, name = 'Pandas')):
        movie = clean_text(getattr(row, 'movie_title'))
        rating = getattr(row, 'rating')

        # find frequency of directors (find favourite and hated directors)
        dir_q = prolog.query("director('" + movie + "',D)")
        for soln in dir_q:
          director = soln['D']
        if director not in directors:
          directors[director] = rating_weights[int(rating)]
        else:
          directors[director] += rating_weights[int(rating)]
        # find frequency of actors (find favourite and hated actors)
        act_q=prolog.query("actor('" + movie + "',A)")
        for soln in act_q:
          actor = soln['A']
          if actor not in actors:
            actors[actor] = rating_weights[int(rating)]
          else:
            actors[actor] += rating_weights[int(rating)]
        # find frequency of genres (find favourite and hated genres)
        act_cg = prolog.query("genre('" + movie + "',G)")
        combi = []
        for soln in act_cg:
          genre = soln['G']
          if genre not in gen:
            gen[genre] = rating_weights[int(rating)]
          else:
            gen[genre] += rating_weights[int(rating)]
          combi.append(genre)

        # update scores based on similarity level with the current movie
        if int(rating) != 2 and int(rating) != 3:
          for i in range(1, 8):
              similar_movies = simple_recommender(movie,i)
              for similar_movie in similar_movies:
                  if similar_movie not in movie_score:
                      movie_score[similar_movie] = rating_weights[int(rating)] * score_weights[i]
                  else:
                      movie_score[similar_movie] += rating_weights[int(rating)] * score_weights[i] #το weight θα το ορίσετε ανα επίπεδο ομοιότητας οι πολύ όμοιες ταινίες θα έχουν μεγαλύτερο βάρος

    # update scores based on general director preferences
    for key, value in directors.items():
      if value >= 3 or value < -3:
        q = prolog.query("director(M,'" + key + "')")
        for soln in q:
            movie = soln['M']
            if movie not in movie_score:
              movie_score[movie] = value/10
            else:
              movie_score[movie] += value/10
        q.close()
    # update scores based on general actor preferences
    for key, value in actors.items():
      if value >= 3 or value < -3:
        q = prolog.query("actor(M,'" + key + "')")
        for soln in q:
            movie = soln['M']
            if movie not in movie_score:
              movie_score[movie] = value/10
            else:
              movie_score[movie] += value/10
        q.close()
    # update scores based on general genre preferences
    for key, value in gen.items():
      if value >= 3 or value < 0:
        q = prolog.query("genre(M,'" + key + "')")
        for soln in q:
            movie = soln['M']
            if movie not in movie_score:
              movie_score[movie] = value/20
            else:
              movie_score[movie] += value/20
        q.close()

    return movie_score

#αυτό είναι ένα παράδειγμα για το πως θα μπορούσε να υλοποιήθει η predict
#έχουμε ορίσει ότι μια ταινία θα έπρεπε να είναι προτεινόμενη αν είχε σκορ > 0
def predict_example(ratings, movie_score):
    real, pred = [], []
    for i, row in enumerate(ratings.itertuples(index = True, name = 'Pandas')):
        movie = clean_text(getattr(row, 'movie_title'))
        rating = getattr(row, 'rating')

        if movie in movie_score: #αν έχουμε σχηματίσει βαθμολογία για την ταινία αυτή
            ## pred.append(int(movie_score[movie] > 0)) #heuristic για το αν μια ταινία είναι προτεινόμενη
            pred.append(int(movie_score[movie]) > 0)
            real.append(int(rating > 3))# έτσι ορίζουμε ότι μια ταινία θα έπρεπε να είναι προτεινόμενη
            #η συνθήκη αυτή δεν μπορεί να αλλάξει
        else: #δεν μπορούμε να προτείνουμε κάτι για το όποιο δεν έχουμε σχηματίσει εικόνα
            pred.append(0)
            real.append(int(rating > 3))

    return real, pred

def get_metrics(real, pred):
    metrics = {}
    metrics["precision"] = precision_score(real, pred)
    metrics["recall"] = recall_score(real, pred)
    metrics["f1"] = f1_score(real, pred)
    return metrics

# %% [markdown]
# Η παραπάνω εκπαιδεύουν, τεστάρουν και μετρούν την απόδοσή του συστήματος στάσεων μας. Για την εκπαίδευση του συστήματος μπορούμε κάθε φορά να χρησιμοποιήσουμε ένα τυχαίο υποσύνολο του training set. Όμως είναι πιθανό το υποσύνολο των ταινιών αυτόν να επηρεάζει τα αποτελέσματα στο training set. Για παράδειγμα από 3 ταινίες στις 10 μπορούν για ένα πείραμα τα αποτελέσματα μας αν είναι ίδια και αυτό να μην οφείλεται στο γεγονός ότι ο ταξινομητής μας τα πηγαίνει καλά στις 3 ταινίες αλλά στο γεγονός ότι οι υπόλοιπες 7 είναι τέτοιες ταινίες που δεν μας βοηθούν καθόλου και αν είχαμε επιλέξει διαφορετικές 3 ταινίες να τα πηγαίναμε χάλια. Οπότε προτείνουμε να τρέξετε κάθε φορά έναν αριθμό πειραμάτων για κάθε υποσύνολο ταινιών π.χ. 10 πειράματα με 3 ταινίες, 10 πειράματα για 20 ταινίες κ.ο.κ. και να κρατήσετε σαν τελικό σκορ το μέσο όρο όλων των πειραμάτων. Έτσι τα αποτελέσματα των αγγλικών σας θα είναι πιο αντικειμενικά.

# %%
train_ratings = pd.read_csv(path + "train_ratings.csv")
test_ratings = pd.read_csv(path + "test_ratings.csv")

# %%
metrics = []
for i in range (10):
    movie_score = train_recommender(train_ratings, rating_weights, score_weights, 10)
    real, pred = predict_example(test_ratings, movie_score)
    metrics.append(get_metrics(real, pred))

for metric in metrics[0].keys():
    print (f"{metric}: {np.mean([m[metric] for m in metrics])}")
# Out:
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# precision: 0.5110217797613104
# recall: 0.9458333333333332
# f1: 0.6629418637513294
